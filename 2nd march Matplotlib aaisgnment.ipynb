# %% [markdown]
# # 2nd March 2023 Assignment

# %% [markdown]
# # Matplotlib

# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [markdown]
# * Matplotlib is a Python library used for creating high-quality data visualizations. It provides a wide range of functions and tools for creating different types of plots, charts, and graphs. Matplotlib is used for exploratory data analysis, data visualization, and presentation of scientific and engineering data.
#
# * Matplotlib is used for several reasons, including:
#
# - Creating publication-quality plots
# - Customizing plots with a wide range of formatting options
# - Building interactive plots and visualizations
# - Visualizing and exploring data
# - Sharing and presenting data insights with others
#
#
# The Pyplot module of Matplotlib provides a simple interface to create a wide range of plots, including:
#
# - Line plots
# - Scatter plots
# - Bar plots
# - Histograms
# - Pie charts
# * There are many more types of plots that can be created using Matplotlib, including heatmaps, contour plots, 3D plots, and many others.

# %% [markdown]
# ### Q2.What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.
#
# * import numpy as np
# - np.random.seed(3)
# - x = 3 + np.random.normal(0, 2, 50)
# - y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# * A scatter plot is a type of plot used to display the relationship between two variables. Each data point in a scatter plot represents an observation in the dataset, and the position of the point on the x and y axes represents the values of the two variables being plotted.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.scatter(x, y)
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# * Use the following data:
# - import numpy as np
#
# - For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# - For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# - For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# - For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# * The subplot() function in Matplotlib is used to create multiple plots in a single figure. It divides the figure into a grid of subplots and specifies the position of each plot in the grid using row, column, and index numbers.

# %%
# data for line 1
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

# data for line 2
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

# data for line 3
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

# data for line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# create a figure with 2 rows and 2 columns
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

# plot line 1 in the first subplot
axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')

# plot line 2 in the second subplot
axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line 2')

# plot line 3 in the third subplot
axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line 3')

# plot line 4 in the fourth subplot
axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')

# adjust the layout and spacing of the subplots
fig.tight_layout()

# display the plot
plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# - box1 = np.random.normal(100, 10, 200)
# - box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# * A box plot, also known as a box-and-whisker plot, is a graphical representation of a dataset that displays the distribution of the data. The box in the plot represents the interquartile range (IQR) which is the range between the first and third quartiles. The line in the box represents the median. The "whiskers" extend from the box and represent the range of the data outside of the IQR. Any points outside of the whiskers are considered outliers.

# %% [markdown]
# * Box plots are used to summarize the distribution of a dataset, especially when comparing multiple datasets. They are particularly useful for identifying differences in the central tendency, spread, and skewness of the data.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

data = [box1, box2]

fig, ax = plt.subplots()

ax.boxplot(data)

boxprops = dict(linestyle='-', linewidth=2, color='darkblue') #adding color to boxplot by using boxprops library
medianprops = dict(linestyle='-', linewidth=2.5, color='orange')
whiskerprops = dict(linestyle='-', linewidth=1.5, color='black')
capprops = dict(linestyle='-', linewidth=1.5, color='black')

ax.boxplot(data, boxprops=boxprops, medianprops=medianprops,
           whiskerprops=whiskerprops, capprops=capprops)



plt.show()

# %% [markdown]
# ## Thank You
